# %% [markdown]
# <a href="https://colab.research.google.com/github/macrodatascience/fmml2021/blob/main/cv2_show_faces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# "Show the faces on images"

import cv2
import os
from google.colab.patches import cv2_imshow
image = cv2.imread("images.jpg")
color_img = image.copy()
filename = os.path.basename('/content/images.jpg')

# open cv works best on grey (gray american) images

gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)

# Use OpenCV's built-in Haar Classifier
haar_classifier = cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')

haar_classifier = cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')

faces = haar_classifier.detectMultiScale(gray_img, scaleFactor=1.1, minNeighbors=5)
print('Number of faces found: {faces}'.format(faces=len(faces)))

for (x, y, width, height) in faces:
  cv2.rectangle(color_img, (x, y), (x+width, y+height), (0, 255, 0), 2)

# show the faces found
cv2_imshow(color_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Number of faces found: 6
# <PIL.Image.Image image mode=RGB size=640x486 at 0x7F3CC0C44210>
# Number of faces found: 0
# <PIL.Image.Image image mode=RGB size=640x486 at 0x7F3CC0BA0050>
