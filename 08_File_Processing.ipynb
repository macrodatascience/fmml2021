# %% [markdown]
# <a href="https://colab.research.google.com/github/macrodatascience/fmml2021/blob/main/08_File_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/aosp-mirror/platform_external_protobuf/master/CONTRIBUTORS.txt
# Out:
# --2021-09-05 02:08:58--  https://raw.githubusercontent.com/aosp-mirror/platform_external_protobuf/master/CONTRIBUTORS.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3924 (3.8K) [text/plain]
# Saving to: ‘CONTRIBUTORS.txt’
#
# CONTRIBUTORS.txt    100%[===================>]   3.83K  --.-KB/s    in 0s
#
# 2021-09-05 02:08:58 (46.9 MB/s) - ‘CONTRIBUTORS.txt’ saved [3924/3924]

# %%
infile_pointer = open("CONTRIBUTORS.txt", "r")
outfile_pointer = open("emails-id.txt", "w")

# %%
print(infile_pointer)
# Out:
# <_io.TextIOWrapper name='CONTRIBUTORS.txt' mode='r' encoding='UTF-8'>

# %%
for each_line in infile_pointer:
  if (each_line.count('@') > 0) and (each_line.count('<') > 0):
      print (each_line)
      outfile_pointer.write(each_line)
infile_pointer.close()
outfile_pointer.close()
# Out:
#   Sanjay Ghemawat <sanjay@google.com>
#
#   Jeff Dean <jeff@google.com>
#
#   Daniel Dulitz <daniel@google.com>
#
#   Paul Haahr <haahr@google.com>
#
#   Corey Anderson <corin@google.com>
#
#   Kenton Varda <kenton@google.com>
#
#   Will Robinson <robinson@google.com>
#
#   Petar Petrov <petar@google.com>
#
#   Brian Duff <bduff@google.com>
#
#   Tom Chao <chaot@google.com>
#
#   Max Cai <maxtroy@google.com>
#
#   Ulas Kirazci <ulas@google.com>
#
#   Jason Hsueh <jasonh@google.com>
#
#   Joseph Schorr <jschorr@google.com>
#
#   Wenbo Zhu <wenboz@google.com>
#
#   Scott Bruce <sbruce@google.com>
#
#   Neal Norwitz <nnorwitz@google.com>
#
#   Jeffrey Yasskin <jyasskin@google.com>
#
#   Ambrose Feinstein <ambrose@google.com>
#
#   Lisa Carey <lcarey@google.com>
#
#   Gregory Kick <gak@google.com>
#
#   Kevin Ko <kevin.s.ko@gmail.com>
#
#   Johan Euphrosine <proppy@aminche.com>
#
#   Ulrich Kunitz <kune@deine-taler.de>
#
#   Leandro Lucarella <llucax@gmail.com>
#
# ...

# %%
# !wget https://github.com/mysql/mysql-server/blob/8.0/Docs/sp-imp-spec.txt

infile_pointer = open("sp-imp-spec.txt", "r")
for each in infile_pointer:
  print(each)
# Out:
# Streaming output truncated to the last 5000 lines.
#         <td id="LC568" class="blob-code blob-code-inner js-file-line">    Unfortunately, we cannot use alternative 1 for the time being, as most</td>
#
#       </tr>
#
#       <tr>
#
#         <td id="L569" class="blob-num js-line-number" data-line-number="569"></td>
#
#         <td id="LC569" class="blob-code blob-code-inner js-file-line">    of the datastructures to be cached (lex and items) are not reentrant</td>
#
#       </tr>
#
#       <tr>
#
#         <td id="L570" class="blob-num js-line-number" data-line-number="570"></td>
#
#         <td id="LC570" class="blob-code blob-code-inner js-file-line">    and thread-safe. (Things are modifed at execution, we have THD pointers</td>
#
#       </tr>
#
#       <tr>
#
#         <td id="L571" class="blob-num js-line-number" data-line-number="571"></td>
#
#         <td id="LC571" class="blob-code blob-code-inner js-file-line">    stored everywhere, etc.)</td>
#
#       </tr>
#
# ...

# %%
# https://github.com/mysql/mysql-server/blob/8.0/Docs/sp-imp-spec.txt
# Write a program to save all lines that start with '-' in a separate file
# Ignore all leading blank characters.

# !wget https://github.com/mysql/mysql-server/blob/8.0/Docs/sp-imp-spec.txt

infile_pointer = open("sp-imp-spec.txt", "r")
outfile_pointer = open("starts_with_hiphen.txt", "w")

for each_line in infile_pointer:
  if len(each_line.lstrip())>0 and each_line.lstrip()[0]=='-':
     print (each_line)
     outfile_pointer.write(each_line)
infile_pointer.close()
outfile_pointer.close()
# Out:
# --2021-09-05 03:23:16--  https://github.com/mysql/mysql-server/blob/8.0/Docs/sp-imp-spec.txt
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sp-imp-spec.txt.3’
#
# sp-imp-spec.txt.3       [ <=>                ] 370.27K  --.-KB/s    in 0.03s
#
# 2021-09-05 03:23:16 (10.6 MB/s) - ‘sp-imp-spec.txt.3’ saved [379154]

# %% [markdown]
# Reference: [Official Python Documentation](https://docs.python.org/3/tutorial/inputoutput.html)
#
# String methods: [Link](https://www.w3schools.com/python/python_ref_string.asp)
